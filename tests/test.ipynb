# %%
import os
import sys

print(os.getcwd())
print(os.path.dirname(__file__))
# Out:
# c:\Users\Mine\OneDrive - sjtu.edu.cn\MineData\Learning\Code\Python\CPGEO\tests
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 import sys
#       4 print(os.getcwd())
# ----> 5 print(os.path.dirname(__file__))
#
# NameError: name '__file__' is not defined
